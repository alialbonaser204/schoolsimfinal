# %%
import pandas as pd



# Laad het CSV bestand
csv_file = "batch_results.csv"
df = pd.read_csv(csv_file)
df
# Out:
#      sim_id  students  coffee_machines  restrict_breaks  avg_wait_time  \
# 0         1        30                2             True     112.766667
# 1         2        30                2             True     123.500000
# 2         3        30                2             True     140.466667
# 3         4        30                2             True     112.733333
# 4         5        30                2             True     117.233333
# ..      ...       ...              ...              ...            ...
# 235     236        60                5             True      58.516667
# 236     237        60                5             True      70.400000
# 237     238        60                5             True      74.883333
# 238     239        60                5             True      70.566667
# 239     240        60                5             True      76.083333
#
#      missed_coffee  no_attempts  total_attempts
# 0                0            0              90
# ...
